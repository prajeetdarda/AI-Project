# %%
import requests, json, textwrap, os, time

TEST_Q = {
    "term": "Daft Punk Get Lucky",
    "media": "music",
    "entity": "song",
    "limit": 1,
    "country": "US",
}
UA = "Mozilla/5.0 (ConnectivitySmokeTest/1.0)"

try:
    r = requests.get("https://itunes.apple.com/search", params=TEST_Q, headers={"User-Agent": UA}, timeout=10)
    print("HTTP:", r.status_code)
    print("URL :", r.url)
    js = r.json()
    print("resultCount:", js.get("resultCount"))
    if js.get("results"):
        item = js["results"][0]
        print("artistName:", item.get("artistName"))
        print("trackName :", item.get("trackName"))
        print("previewUrl:", item.get("previewUrl"))
    else:
        print("No results payload:", js)
except Exception as e:
    print("❌ Exception:", repr(e))
# Out:
# HTTP: 403
# URL : https://itunes.apple.com/search?term=Daft+Punk+Get+Lucky&media=music&entity=song&limit=1&country=US
# ❌ Exception: JSONDecodeError('Expecting value: line 1 column 1 (char 0)')

# %%
# JUPYTER NOTEBOOK CELL — FAST downloader using Deezer previews (no auth), verbose + resume

import os, re, csv, time, sys, random, math
import requests
import pandas as pd
from pathlib import Path
from rapidfuzz import fuzz
from tqdm.auto import tqdm

# ============== CONFIG ==============
DATA_DIR         = "../../data"
RAW_FILE         = "SpotifyFeatures.csv"

OUT_DIR          = "../input"
OUT_CSV_NAME     = "songs_dataset_6k.csv"
WORK_DIR         = "../work"
AUDIO_DIR        = "../output/previews"

TARGET_TOTAL     = 6000                 # previews to collect
QPS              = 10.0                 # throttle (requests/sec)
RETRIES          = 1                    # quick retry
HTTP_TIMEOUT     = 8                    # per request timeout
USER_AGENT       = "Mozilla/5.0 (FastDeezerSampler/1.0)"
RANDOM_SEED      = 42
LOG_EVERY_N_OK   = 50
MIN_SCORE_ACCEPT = 66.0                 # fuzzy match threshold (artist+title)
RESULTS_LIMIT    = 5                    # Deezer top-N to scan

# ============== HELPERS ==============
def clean_text(s: str) -> str:
    s = (s or "")
    s = s.replace("’","'").replace("‘","'").replace("“",'"').replace("”",'"')
    s = re.sub(r"\(.*?\)|\[.*?\]", " ", s)
    s = re.sub(r"\s+(feat|ft)\.?\s+.*$", " ", s, flags=re.IGNORECASE)
    s = re.sub(r"\s+-\s*(radio|single|album|remaster|edit).*$", " ", s, flags=re.IGNORECASE)
    s = re.sub(r"\s+", " ", s).strip().lower()
    return s

def score_candidate(q_artist: str, q_track: str, cand_artist: str, cand_title: str) -> float:
    # weight track slightly higher than artist
    sa = fuzz.token_set_ratio(q_artist, clean_text(cand_artist))
    st = fuzz.token_set_ratio(q_track,  clean_text(cand_title))
    return 0.4 * sa + 0.6 * st

def deezer_search_preview(artist: str, track: str, *, session: requests.Session):
    """
    Use Deezer search to find a 30s MP3 preview.
    Query both (artist+track) and (track only) quickly and pick best-scoring.
    Returns: (preview_url, best_score, matched_artist, matched_title) or (None, 0, None, None)
    """
    qA, qT = clean_text(artist), clean_text(track)
    best = (None, 0.0, None, None)

    # Pass 1: artist+track
    q = f'artist:"{artist}" track:"{track}"'
    params = {"q": q, "limit": RESULTS_LIMIT}
    try:
        r = session.get("https://api.deezer.com/search", params=params, timeout=HTTP_TIMEOUT)
        js = r.json()
        for item in js.get("data", []):
            cand_artist = item.get("artist", {}).get("name", "")
            cand_title  = item.get("title", "")
            sc = score_candidate(qA, qT, cand_artist, cand_title)
            if sc > best[1] and item.get("preview"):
                best = (item["preview"], sc, cand_artist, cand_title)
                if best[1] >= MIN_SCORE_ACCEPT:
                    return best
    except Exception:
        pass

    # Pass 2: track-only
    q = f'track:"{track}"'
    params = {"q": q, "limit": RESULTS_LIMIT}
    try:
        r = session.get("https://api.deezer.com/search", params=params, timeout=HTTP_TIMEOUT)
        js = r.json()
        for item in js.get("data", []):
            cand_artist = item.get("artist", {}).get("name", "")
            cand_title  = item.get("title", "")
            sc = score_candidate(qA, qT, cand_artist, cand_title)
            if sc > best[1] and item.get("preview"):
                best = (item["preview"], sc, cand_artist, cand_title)
                if best[1] >= MIN_SCORE_ACCEPT:
                    return best
    except Exception:
        pass

    return best if best[0] else (None, 0.0, None, None)

def slugify(s: str) -> str:
    return re.sub(r'[^a-zA-Z0-9]+', '_', (s or "").lower()).strip('_')[:60]

def download(url: str, dst: Path, sess: requests.Session):
    try:
        with sess.get(url, stream=True, timeout=30) as resp:
            if resp.status_code != 200:
                return False, resp.status_code, 0
            total = 0
            with open(dst, "wb") as f:
                for ch in resp.iter_content(64*1024):
                    if ch:
                        f.write(ch); total += len(ch)
        return True, 200, total
    except Exception:
        return False, 0, 0

# ============== SETUP ==============
data_dir  = Path(DATA_DIR); raw_path = data_dir / RAW_FILE
out_dir   = Path(OUT_DIR);  work_dir = Path(WORK_DIR)
audio_dir = Path(AUDIO_DIR); out_csv = out_dir / OUT_CSV_NAME

out_dir.mkdir(parents=True, exist_ok=True)
work_dir.mkdir(parents=True, exist_ok=True)
audio_dir.mkdir(parents=True, exist_ok=True)

print("Loading:", raw_path)
df = pd.read_csv(raw_path)
if not {"artist_name","track_name"}.issubset(df.columns):
    raise ValueError("CSV must contain 'artist_name' and 'track_name' columns")

# Randomize order (we no longer enforce per-genre quotas)
df = df.sample(frac=1.0, random_state=RANDOM_SEED).reset_index(drop=True)

# Manifest
manifest_path = work_dir / "deezer_manifest_verbose.csv"
fields = ["row_idx","artist","track","matched_artist","matched_title","score",
          "preview_url","audio_file","status","http_status","bytes","notes"]
mf = open(manifest_path, "w", newline="", encoding="utf-8")
mw = csv.DictWriter(mf, fieldnames=fields); mw.writeheader()

# Resume
existing = {p.name for p in audio_dir.glob("*.mp3")}
selected = []
ok = 0
start = time.time()
sleep = 1.0 / max(0.1, QPS)

# If an earlier CSV exists, load to continue
if out_csv.exists():
    try:
        prev = pd.read_csv(out_csv)
        if {"audio_file"}.issubset(prev.columns):
            already = {str(x) for x in prev["audio_file"].dropna().astype(str)}
            # Only count those that exist on disk
            ok_files = already & existing
            if ok_files:
                keep_rows = prev[prev["audio_file"].isin(list(ok_files))].to_dict("records")
                selected.extend(keep_rows)
                ok = len(keep_rows)
                print(f"Resuming: {ok} rows already on disk & in CSV")
    except Exception:
        pass

try:
    pbar = tqdm(total=TARGET_TOTAL, unit="trk", desc="Downloading previews (Deezer)", leave=True)
    pbar.update(min(ok, TARGET_TOTAL))

    with requests.Session() as sess:
        sess.headers.update({"User-Agent": USER_AGENT, "Accept": "application/json"})

        for i, row in df.iterrows():
            if ok >= TARGET_TOTAL:
                break

            artist = str(row["artist_name"]).strip()
            track  = str(row["track_name"]).strip()
            if not artist or not track:
                mw.writerow({"row_idx": i, "artist": artist, "track": track,
                             "matched_artist":"", "matched_title":"", "score":"",
                             "preview_url":"", "audio_file":"", "status":"skip_missing",
                             "http_status":"", "bytes":"", "notes":""})
                continue

            base   = f"{slugify(artist)}_{slugify(track)}_{i}"
            fname  = f"{base}.mp3"
            fpath  = audio_dir / fname

            # Skip existing file (resume)
            if fname in existing and fpath.exists() and fpath.stat().st_size > 0:
                out_row = row.to_dict()
                out_row["preview_url"] = ""
                out_row["audio_file"]  = fname
                selected.append(out_row)
                ok += 1
                pbar.update(1)
                if ok % LOG_EVERY_N_OK == 0:
                    elapsed = time.time() - start
                    rate = ok / max(1e-6, elapsed)
                    tqdm.write(f"[resume] ok={ok}/{TARGET_TOTAL}  rate={rate:.2f} trk/s  elapsed={elapsed/60:.1f}m")
                continue

            # Lookup on Deezer
            preview_url, score, m_artist, m_title = None, 0.0, None, None
            for _ in range(RETRIES + 1):
                preview_url, score, m_artist, m_title = deezer_search_preview(
                    artist, track, session=sess
                )
                if preview_url:
                    break
                time.sleep(0.2)

            if not preview_url:
                mw.writerow({"row_idx": i, "artist": artist, "track": track,
                             "matched_artist":"", "matched_title":"", "score": round(score,1),
                             "preview_url":"", "audio_file": fname, "status":"not_found",
                             "http_status":"", "bytes":"", "notes":""})
                tqdm.write(f"[miss] {i}  {artist} — {track}  (score={score:.1f})")
                time.sleep(sleep)
                continue

            # Download MP3 preview
            ok_dl, code, nbytes = download(preview_url, fpath, sess)
            if ok_dl:
                out_row = row.to_dict()
                out_row["preview_url"] = preview_url
                out_row["audio_file"]  = fname
                selected.append(out_row)
                mw.writerow({"row_idx": i, "artist": artist, "track": track,
                             "matched_artist": m_artist or "", "matched_title": m_title or "",
                             "score": round(score,1), "preview_url": preview_url, "audio_file": fname,
                             "status":"downloaded", "http_status": code, "bytes": nbytes, "notes":""})
                ok += 1
                pbar.update(1)
                if ok % LOG_EVERY_N_OK == 0:
                    elapsed = time.time() - start
                    rate = ok / max(1e-6, elapsed)
                    tqdm.write(f"[ok] {ok}/{TARGET_TOTAL}  {artist} — {track}  bytes={nbytes}  rate={rate:.2f} trk/s")
            else:
                mw.writerow({"row_idx": i, "artist": artist, "track": track,
                             "matched_artist": m_artist or "", "matched_title": m_title or "",
                             "score": round(score,1), "preview_url": preview_url, "audio_file": fname,
                             "status":"download_failed", "http_status": code, "bytes": nbytes, "notes":""})
                tqdm.write(f"[dl-fail] {i}  {artist} — {track}  http={code}")

            time.sleep(1.0 / max(0.1, QPS))

    pbar.close()
finally:
    mf.close()

# Save final CSV
out_df = pd.DataFrame(selected)
if len(out_df) > TARGET_TOTAL:
    out_df = out_df.sample(n=TARGET_TOTAL, random_state=4242).reset_index(drop=True)
out_dir.mkdir(parents=True, exist_ok=True)
out_df.to_csv(out_csv, index=False)

elapsed = time.time() - start
rate = (len(out_df) / max(1e-6, elapsed))
print("\n======== Summary ========")
print(f"Target total: {TARGET_TOTAL}")
print(f"Selected rows (downloaded/resumed): {len(out_df)}")
print(f"Throughput: {rate:.2f} tracks/sec  |  Elapsed: {elapsed/60:.1f} min")
print(f"✅ Final CSV: {out_csv}")
print(f"🎵 Audio dir: {AUDIO_DIR}")
print(f"📝 Manifest:  {manifest_path}")
# Out:
# Loading: ../../data/SpotifyFeatures.csv
# Downloading previews (Deezer):   0%|          | 0/6000 [00:00<?, ?trk/s]
# [miss] 23  Randy Edelman — A Steep But Beautiful Climb  (score=0.0)
# [ok] 50/6000  Mike Baldwin — Vodka & Cigarettes  bytes=479827  rate=0.82 trk/s
# [miss] 57  Kami-sama, I have noticed — 破滅のオレンジ  (score=0.0)
# [miss] 63  Chief Keef — I Just Wanna (feat. Mac Miller)  (score=0.0)
# [ok] 100/6000  Moby — Sunday (B-Sides)  bytes=479827  rate=0.82 trk/s
# [miss] 137  Wolfgang Amadeus Mozart — Requiem in D Minor, K. 626: 1. Introitus: Requiem - Live  (score=0.0)
# [miss] 143  James Horner — Iris: Pt. 2 - Instrumental  (score=0.0)
# [ok] 150/6000  Cults — Go Outside  bytes=479827  rate=0.82 trk/s
# [miss] 156  Chuck Loeb — Love Is All (feat. Kim Waters)  (score=0.0)
# [miss] 158  Jim Norton — Clean It off, B---  (score=0.0)
# [miss] 203  Hillsong Worship — Thank You Jesus - Alternate Version/Live  (score=0.0)
# [ok] 200/6000  NEEDTOBREATHE — Forever On Your Side (with JOHNNYSWIM)  bytes=479827  rate=0.82 trk/s
# [ok] 250/6000  Too $hort — Blow the Whistle  bytes=479827  rate=0.84 trk/s
# [miss] 261  Trentemøller — One Eye Open - Trentemøller Remix Hbt Edit  (score=0.0)
# [miss] 262  Smino — SUMMER SALT (with Bari)  (score=0.0)
# [miss] 266  Third Eye Blind — Deep Inside of You - 2008 Version  (score=0.0)
# [miss] 290  ScHoolboy Q — X (with 2 Chainz & Saudi)  (score=0.0)
# [miss] 298  Bad Wolves — Hear Me Now (feat. DIAMANTE)[Acoustic]  (score=0.0)
# [miss] 302  Lewis Black — Congressional Correspondents Dinner  (score=0.0)
# [miss] 303  Franz Joseph Haydn — Piano Sonata No. 24 in A Major, Hob.XVI:26: I: Allegro moderato  (score=0.0)
# [miss] 304  Andrew Dice Clay — Black Chicks - Live at Rascals Comedy Club (NJ) / 1990  (score=0.0)
# [miss] 309  Edvard Grieg — Lyric Pieces Book IV, Op.47: No. 3 Melodie  (score=0.0)
# [miss] 314  Darlene Zschech — Beloved (When I Survey) - Live  (score=0.0)
# [miss] 316  Maxwell — Lifetime - Uncut  (score=0.0)
# [miss] 2584  Daddy Yankee — Donde Estan Las Gatas (feat. Nicky Jam)  (score=0.0)
# [ok] 2450/6000  Rise Against — Behind Closed Doors  bytes=479827  rate=0.81 trk/s
# [miss] 2600  Andrew Dice Clay — Apartment Life - Live at Rascals Comedy Club (NJ) / 1990  (score=0.0)
# [miss] 2608  Jean-Baptiste Lully — Phaeton, Prologue - Le retour de l'Âge d'or: Ouverture  (score=0.0)
# [miss] 2633  Randy Newman — Lucy - Remastered Awakenings - Original Motion Picture Soundtrack  (score=0.0)
# [ok] 2500/6000  Lil Dicky — Freaky Friday (feat. Chris Brown)  bytes=479827  rate=0.82 trk/s
# [miss] 2652  Keith Jarrett — Köln, January 24, 1975, Pt. II A - Live  (score=0.0)
# [miss] 2663  Calle 13 — Querido Fbi  (score=0.0)
# [miss] 2667  Richard Pryor — White and Black People - Live at The John F. Kennedy Center For The Performing Arts, Washington, DC, 9/3/78 and City Center Of Music And Drama, New York, NY, 9/19/78 (Remastered Version)  (score=0.0)
# [miss] 2676  Hillsong Worship — The Father's Heart - Live At Dominion Theatre, London/2010  (score=0.0)
# [miss] 2678  Sarah Silverman — You're Gonna Die Soon - Album Version (Edited)  (score=0.0)
# [miss] 2683  Patrick Sweany — After Awhile  (score=0.0)
# [miss] 2689  Max Richter — Afterimage 2  (score=0.0)
# [ok] 2550/6000  Future — Honest  bytes=479827  rate=0.81 trk/s
# [miss] 2716  Dolly Parton — Lovesick Blues - With Special Guest, Patsy Cline  (score=0.0)
# [miss] 2723  Father John Misty — Just Dumb Enough to Try  (score=0.0)
# [miss] 2728  Thievery Corporation — Quem Me Leva (feat. Elin Melgarejo)  (score=0.0)
# [miss] 2753  Jonas Kaufmann — Der Freischütz, J.277 / Act 1: "Nein, länger trag' ich nicht die Quälen...Durch die Wälder, durch die Auen"  (score=0.0)
# [ok] 2600/6000  7eventh Time Down — The 99  bytes=479827  rate=0.81 trk/s
# [miss] 2798  Hunter Hayes — Dear God - Recorded at Woodshed Recording Malibu  (score=0.0)
# [miss] 2803  Comedian Bob Marley — Dad's Pills  (score=0.0)
# [ok] 2650/6000  Big Sean — Beware  bytes=479827  rate=0.81 trk/s
# [miss] 2833  Yves Tumor — The Feeling When You Walk Away  (score=0.0)
# [miss] 2851  Hector & Tito — Homenaje A Vico C (Medley) - Live  (score=0.0)
# [ok] 2700/6000  Mobb Deep — Shook Ones, Pt. II  bytes=479827  rate=0.81 trk/s
# [miss] 2873  Vybz Kartel — Punani a Mi Best Friend  (score=0.0)
# [miss] 2882  Derek & The Dominos — Tell The Truth - Remixed Version  (score=0.0)
# [ok] 2750/6000  Rihanna — Don't Stop The Music  bytes=479827  rate=0.81 trk/s
# [miss] 2953  The Flatliners — Tail Feathers  (score=0.0)
# [ok] 2800/6000  Austin Wintory — Top Hats and Sword Canes  bytes=479827  rate=0.81 trk/s
# [miss] 2988  Ray LaMontagne — Such A Simple Thing - Recorded at Sound Stage Studios Nashville  (score=0.0)
# [miss] 3339  The Mamas & The Papas — Dream A Little Dream Of Me - Album Version With Introduction  (score=0.0)
# [ok] 3150/6000  Anna Moffo — Verdi: La Traviata: Dell'invito trascorsa e gia l'ora? - Act One  bytes=479827  rate=0.82 trk/s
# [miss] 3343  Bobcat Goldthwait — Jack And Bobby In Hell, Alan Thicke, Polar Bear, and Chris Reeve  (score=0.0)
# [miss] 3349  Modest Mouse — Styrofoam Boots/It's All Nice on Ice, Alright  (score=0.0)
# [miss] 3369  The Game — From Adam (feat. Lil Wayne)  (score=0.0)
# [miss] 3377  John Williams — Schindlers Liste: Thema (Schindlers Liste): Theme (Shindler's List)  (score=0.0)
# [miss] 3393  Crosby, Stills & Nash — Wasted On The Way - Remastered  (score=0.0)
# [ok] 3200/6000  Robyn — Ever Again  bytes=479827  rate=0.81 trk/s
# [miss] 3427  Rejjie Snow — Egyptian Luvr (feat. Aminé and Dana Williams)  (score=0.0)
# [miss] 3435  Austin Wintory — No Field Was Formed  (score=0.0)
# [ok] 3250/6000  David Bowie — As The World Falls Down  bytes=479827  rate=0.81 trk/s
# [miss] 3449  Willie Nelson — Pancho and Lefty  (score=0.0)
# [miss] 3452  DaniLeigh — I Do It 4 (feat. Lil Yachty)  (score=0.0)
# [miss] 3464  Joe Hisaishi — メドレー:さんぽ/風のとおり道/ねこバス/となりのトトロ - Jazz コレクション Vol.1 〜映画「となりのトトロ」より〜  (score=0.0)
# [ok] 3300/6000  Jauz — OK!  bytes=479827  rate=0.81 trk/s
# [miss] 3510  Mili — Though Our Paths May Diverge (Goblin Slayer Episode Seven inserted song)  (score=0.0)
# [miss] 3523  The Bloody Beetroots — Hollywood Surf Club (feat. Mr. Talkbox)  (score=0.0)
# [miss] 3530  Crosby, Stills & Nash — Marrakesh Express - Remastered  (score=0.0)
# [ok] 3350/6000  Ty Dolla $ign — Blasé (feat. Future & Rae Sremmurd) - Louis The Child Remix  bytes=479827  rate=0.81 trk/s
# [miss] 3579  Big Sean — Big Bidness (& Metro Boomin)  (score=0.0)
# [miss] 3583  Aimer — Ninelie (with chelly) - Instrumental  (score=0.0)
# [miss] 3584  Kenji Kanemasu — ひとりぼっちはやめた(「ホーホケキョとなりの山田くん」より)  (score=0.0)
# [miss] 3604  川田まみ — Contrail ~軌跡~  (score=0.0)
# [ok] 3400/6000  Limp Bizkit — Rollin' (Air Raid Vehicle)  bytes=479827  rate=0.81 trk/s
# [miss] 3619  Yella Beezy — What I Did (feat. Kevin Gates)  (score=0.0)
# [miss] 3622  KirbLaGoop — I Can't Feel My Face (feat. Lil Peep & Mackned)  (score=0.0)
# [miss] 3627  Vic Damone — After the Lights Go Down Low  (score=0.0)
# [ok] 3450/6000  KeKe Wyatt — Tennessee Whiskey  bytes=479827  rate=0.81 trk/s
# [miss] 3691  Tory Lanez — DrIP DrIp Drip (feat. Meek Mill)  (score=0.0)
# [ok] 3500/6000  Mike Bahía — Tarde  bytes=479827  rate=0.81 trk/s
# [miss] 3718  Jimi Hendrix — Who Knows - Live At Filmore East, New York/1970/1997 Digital Remaster  (score=0.0)
# [miss] 3761  SOB X RBE — Intro (Gangin) (feat. DaBoii, Slimmy B, Yhung T.O. & Lul G)  (score=0.0)
# [ok] 3550/6000  Chip Taylor — F**K All the Perfect People  bytes=479827  rate=0.81 trk/s
# [miss] 3765  Joe Hisaishi — Le Petit Poucet - Main Theme  (score=0.0)
# [miss] 3774  Ari Lennox — Shea Butter Baby (with J. Cole)  (score=0.0)
# [miss] 3778  Smino — KRUSHED ICE (with Valee)  (score=0.0)
# [miss] 3787  Randy Newman — Biggest Brand in Racing  (score=0.0)
# [miss] 3797  Saverio Mercadante — Le sette ultime parole di nostro Signore sulla croce: Qual Giglio Candido  (score=0.0)
# [miss] 3807  KBong — Middle of the Ocean (feat. Stick Figure)  (score=0.0)
# [miss] 3817  Samfree — 無限の色と音の世界  (score=0.0)
# [ok] 3600/6000  Scatman Crothers — Papa (I Don't Treat That Little Girl Mean)  bytes=479827  rate=0.81 trk/s
# [miss] 3826  Georges Bizet — Carmen (1997 - Remaster), Act III: Reposons-nous une heure ici, mes camarades  (score=0.0)
# [miss] 3829  Nujabes — Latitude -remix (feat. Five Deez)  (score=0.0)
# [miss] 3830  Franco Escamilla — 5 de Junio la Corneta (En Vivo)  (score=0.0)
# [miss] 3848  Chorus — Kaatuka Pittala  (score=0.0)
# [miss] 3854  Barbara Hendricks — C’est l’extase Op. 58 Nr. 5: C’est l’extase Op. 58 Nr. 5  (score=0.0)
# [miss] 3858  2 Chainz — Forgiven (feat. Marsha Ambrosius)  (score=0.0)
# [miss] 3868  Soraru — ありふれた魔法  (score=0.0)
# [miss] 3871  The Flatliners — This Song Is Like Thunder and Lightning in a Wide Open Field  (score=0.0)
# [ok] 3650/6000  Capcom Sound Team — 海と陸の共震/ラギアクルス  bytes=479827  rate=0.81 trk/s
# [miss] 3881  Q-Tip — Vivrant Thing - Club Mix  (score=0.0)
# [miss] 3886  Ludwig van Beethoven — Piano Concerto No.3 In C Minor, Op.37: 1. Allegro con brio - Live  (score=0.0)
# [miss] 3888  NOFX — The Marxist Brothers  (score=0.0)
# [miss] 3894  Yuki Hayashi — 心を支配していく闇  (score=0.0)
# [miss] 3913  Domo Genesis — Consecutive Normal Punches (feat. Buddy)  (score=0.0)
# [miss] 3918  Nina Simone — Strange Fruit - Live In New York/1965  (score=0.0)
# [miss] 3922  Oumou Sangaré — Yere faga (feat. Tony Allen)  (score=0.0)
# [ok] 3700/6000  Kesha — Finding You  bytes=479827  rate=0.81 trk/s
# [miss] 3958  Quavo — CHAMPAGNE ROSÉ (feat. Madonna & Cardi B)  (score=0.0)
# [miss] 3978  Georges Bizet — Bizet: Carmen: L'amour est un oiseau rebelle: Habanera - Act One  (score=0.0)
# [ok] 3750/6000  Szun Waves — Temple  bytes=479827  rate=0.81 trk/s
# [miss] 3992  TroyBoi — Afterhours feat. Diplo & Nina Sky  (score=0.0)
# [miss] 4017  Van Morrison — Vanlose Stairway  (score=0.0)
# [ok] 3800/6000  Michael Giacchino — Jurassic World Suite  bytes=479827  rate=0.81 trk/s
# [miss] 4043  Leo Brouwer — El Decamerón Negro: I. La Arpa de Guerrero  (score=0.0)
# [miss] 4063  Pete Rock — Back On Da Block - Instrumental  (score=0.0)
# [miss] 4091  Revol — Ellos Quieren (feat. Cosculluela)  (score=0.0)
# [ok] 3850/6000  Kendrick Lamar — She Needs Me (Remix)  bytes=479827  rate=0.81 trk/s
# [miss] 4097  Riot Ten — Pit Boss (feat. DJ Paul) - Badklaat Remix  (score=0.0)
# [ok] 3900/6000  Georges Bizet — Carmen, WD 31, Act I: Près des remparts de Séville (Live)  bytes=479827  rate=0.81 trk/s
# [miss] 4155  Bethel Music — It Is Well (Radio Mix)  (score=0.0)
# [miss] 4160  The Notorious B.I.G. — Get Money - Performed by Junior M.A.F.I.A.  (score=0.0)
# [miss] 4188  Linda Ronstadt — Blue Bayou - Remastered LP Version  (score=0.0)
# [ok] 3950/6000  fun. — We Are Young (feat. Janelle Monáe)  bytes=479827  rate=0.81 trk/s
# [miss] 4204  King Princess — I Know (feat. Fiona Apple) - RISE Recording  (score=0.0)
# [miss] 4207  Syn Cole — Getaway - VIP Mix  (score=0.0)
# [ok] 4000/6000  Wendell B — Mississippi Girl  bytes=479827  rate=0.81 trk/s
# [miss] 4258  Nujabes — Eclipse (feat. Substantial)  (score=0.0)
# [miss] 4264  Bedřich Smetana — On the Sea Shore - a memory (Na brehu morskem - vzpominka)  (score=0.0)
# [miss] 4272  Josh Heinrichs — Make a Way (feat. Inna Vision)  (score=0.0)
# [miss] 4275  Arin Ray — We Ain't Homies (feat. YG)  (score=0.0)
# [miss] 4295  Kankick — Citywalk: Broad's Groove  (score=0.0)
# [miss] 4297  SOJA — Your Song - feat. Damian 'Jr. Gong' Marley  (score=0.0)
# [miss] 4302  Gioachino Rossini — Il barbiere di Siviglia / Act 1: No.2 Cavatina: "Largo al factotum"  (score=0.0)
# [ok] 4050/6000  Jars Of Clay — Flood  bytes=479827  rate=0.81 trk/s
# [miss] 4334  Jules Massenet — Manon Ballet - Arranged and orchestrated by Leighton Lucas with the collaboration of Hilda Gaunt / Act 2: Scene 2 - Des Grieux's lodgings  (score=0.0)
# [miss] 4348  Lil' Kim — Not Tonight (feat. Da Brat, Left Eye, Missy "Misdemeanor" Elliott and Angie Martinez - Remix  (score=0.0)
# [miss] 4352  Thievery Corporation — Décollage (feat. Lou Lou Ghelichkhani)  (score=0.0)
# [miss] 4356  Georg Philipp Telemann — Ouverture-Suite in D Minor, TWV 55:d2: VII. Menuet I  (score=0.0)
# [ok] 4100/6000  Zion & Lennox — Estás Tentándome  bytes=479827  rate=0.81 trk/s
# [miss] 4363  Soda Stereo — Persiana Americana - Me Verás Volver Gira 2007  (score=0.0)
# [miss] 4408  EZ El Ezeta — Lacoste (Remix) (feat. Mozart La Para, Nejo, Nengo Flow & Darell)  (score=0.0)
# [ok] 4150/6000  Katy Perry — Part Of Me  bytes=479827  rate=0.81 trk/s
# [miss] 4417  Avantasia — The Raven Child (feat. Hansi Kürsch & Jorn Lande)  (score=0.0)
# [miss] 4446  Antonín Dvořák — Rusalka, Op. 114, B. 203, Act III: Prelude. Allegro (Live)  (score=0.0)
# [miss] 4456  Yuki Hayashi — 自由で平等な場所  (score=0.0)
# [ok] 4200/6000  Bad Suns — Dancing On Quicksand  bytes=479827  rate=0.81 trk/s
# [miss] 4476  John Pinette — The Television Warranty  (score=0.0)
# [miss] 4505  Eagles — Journey of the Sorcerer - Eagles 2013 Remaster  (score=0.0)
# [miss] 4509  Moosh & Twist — All That I Know (feat. Hoodie Allen)  (score=0.0)
# [ok] 4250/6000  The Supervillains — Irukandji  bytes=479827  rate=0.81 trk/s
# [miss] 4524  Tobi Lou — Birthday Boy (feat. Zack Villere)  (score=0.0)
# [miss] 4526  Yoke Lore — Truly Madly Deeply - Recorded at Spotify Studios NYC  (score=0.0)
# [miss] 4527  The Who — Amazing Journey - Remixed Album Version  (score=0.0)
# [miss] 4542  Wonderful★opportunity! — インフルエンサー・イズ・デッド  (score=0.0)
# [miss] 4554  Young Dolph — Whole World (feat. Kash Doll)  (score=0.0)
# [miss] 4556  T-Pain — RIP to the Parking Lot (feat. Boosie Badazz)  (score=0.0)
# [ok] 4300/6000  Tigers Jaw — Gypsy  bytes=479827  rate=0.81 trk/s
# [miss] 4578  Capcom Sound Team — VS Lumine〜The second form  (score=0.0)
# [ok] 4350/6000  Mick Jenkins — Martyrs  bytes=479827  rate=0.81 trk/s
# [miss] 4638  Jay Rock — Tap Out (feat. Jeremih)  (score=0.0)
# [miss] 4659  SG Lewis — Hurting (feat. AlunaGeorge)  (score=0.0)
# [ok] 4400/6000  Ruggero Leoncavallo — Pagliacci / Act 1: "Nedda! Silvio, a quest'ora"  bytes=479827  rate=0.81 trk/s
# [miss] 4699  Nina Simone — Since I Fell for You - Original Mix  (score=0.0)
# [miss] 4727  Moby — Falling Rain and Light - Glory Remix  (score=0.0)
# [ok] 4450/6000  Brian Regan — Money Confusion  bytes=479827  rate=0.81 trk/s
# [miss] 4744  Martin & les fées — La petite flamme (par Lorie Pester)  (score=0.0)
# [miss] 4747  Tedeschi Trucks Band — Bring It on Home to Me – Live at Spotify NYC  (score=0.0)
# [miss] 4763  Martin & les fées — Iris (par Paul Ventimila, Lorie Pester & Véronique Jannot)  (score=0.0)
# [miss] 4777  Cardi B — Lick (feat. Offset)  (score=0.0)
# [ok] 4500/6000  Phantogram — Fall In Love  bytes=479827  rate=0.81 trk/s
# [miss] 4797  Ludwig van Beethoven — Symphony No.2 in D, Op.36: 2. Larghetto  (score=0.0)
# [miss] 4823  Richard Heuberger — Der Opernball. Overture: Im Chambre Separée  (score=0.0)
# [miss] 4834  OutKast — The Way You Move (feat. Sleepy Brown) - Club Mix  (score=0.0)
# [ok] 4550/6000  SoMo — I Wish  bytes=479827  rate=0.81 trk/s
# [ok] 4600/6000  Marilyn Manson — The Dope Show  bytes=479827  rate=0.81 trk/s
# [miss] 4886  SILENT SIREN — Jyoshikou Sensou  (score=0.0)
# [ok] 4900/6000  Aziz Ansari — Texting With Girls  bytes=479827  rate=0.80 trk/s
# [miss] 5218  Kami-sama, I have noticed — 天罰有れかしと願う  (score=0.0)
# [miss] 5224  Dr. Dog — Heart It Races - Dr Dog Version  (score=0.0)
# [miss] 5228  Three Houses Down — Ghetto World - Move Your Feet to This Reggae Beat  (score=0.0)
# [miss] 5243  Depeche Mode — Personal Jesus - Original Seven Inch Version  (score=0.0)
# [miss] 5249  Action Bronson — Swerve On Em (feat. A$AP Rocky)  (score=0.0)
# [ok] 4950/6000  Shoreline Mafia — Molly Water (feat. Fenix Flexin & OhGeesy)  bytes=479827  rate=0.80 trk/s
# [miss] 5274  Eric Bellinger — Dirty Dancin' (feat. Ne-Yo)  (score=0.0)
# [miss] 5303  Joe Hisaishi — 晴れた日に... - スーパー・サウンド・コレクション Vol.2 魔女の宅急便組曲  (score=0.0)
# [ok] 5000/6000  Pond — Giant Tortoise  bytes=479827  rate=0.80 trk/s
# [miss] 5332  Mike WiLL Made-It — Aries (YuGo) Part 2 (with Rae Sremmurd & Big Sean feat. Quavo & Pharrell)  (score=0.0)
# [miss] 5344  Lil Baby — Time (feat. Meek Mill)  (score=0.0)
# [ok] 5050/6000  Aretha Franklin — Freeway Of Love  bytes=479827  rate=0.80 trk/s
# [miss] 5373  Martin & les fées — Sous la peinture (par Paul Ventimila, Arielle Dombasle, Véronique Jannot, Michèle Laroque, Lorie Pester, Lisa Angell, Anggun, Sara Carreira & Julie Zenatti)  (score=0.0)
# [miss] 5380  Migos — Kelly Price (feat. Travis Scott)  (score=0.0)
# [miss] 5404  Lil Wayne — Let It Fly (feat. Travis Scott)  (score=0.0)
# [ok] 5100/6000  Ariana Grande — better off  bytes=479827  rate=0.80 trk/s
# [miss] 5450  Kendrick Lamar — The Recipe (Black Hippy Remix) - Bonus Track  (score=0.0)
# [miss] 5467  Bob Marley & The Wailers — Waiting In Vain - US Version  (score=0.0)
# [miss] 5472  Soraru — Kagerou Days - Mekakucity Days Ver.  (score=0.0)
# [ok] 5150/6000  Buck-O-Nine — My Town  bytes=479827  rate=0.80 trk/s
# [miss] 5478  Hunter Hayes — Attention - Recorded at Woodshed Recording Malibu  (score=0.0)
# [miss] 5481  The Smashing Pumpkins — Cherub Rock - Remastered 2011  (score=0.0)
# [miss] 5491  Terry Gilkyson — Probiers Mal Mit Gemütlichkeit (The Bare Necessities) [Aus Das Dschungelbuch] [Feat. Florian Bischof]  (score=0.0)
# [miss] 5499  Andrew Dice Clay — Mother & Son - Live At Dangerfield's/1989  (score=0.0)
# [miss] 5518  Comedian Bob Marley — Copperzilla vs Dr Miyagi, & The Michelin Man  (score=0.0)
# [miss] 5531  Third Eye Blind — Wounded - 2008 Version  (score=0.0)
# [ok] 5200/6000  Ty Dolla $ign — Watching (feat. Meek Mill)  bytes=479827  rate=0.80 trk/s
# [miss] 5547  Andrew Dice Clay — Holiday Season - Live At Dangerfield's/1989  (score=0.0)
# [miss] 5548  Smino — KRUSHED ICE (with Valee)  (score=0.0)
# [miss] 5566  Usher — Confessions Part II - Confessions Special Edition Version  (score=0.0)
# [miss] 5570  Frédéric Chopin — チェロ・ソナタ ト短調 作品65 III. Largo  (score=0.0)
# [ok] 5250/6000  Puma Blue — Bruise Cruise  bytes=479827  rate=0.80 trk/s
# [miss] 5589  Antonín Dvořák — Silent Woods, Op.68/5 - version for Cello and Piano: Silent Woods  (score=0.0)
# [miss] 5595  Ice Cube — Until We Rich - Feat. Krayzie Bone  (score=0.0)
# [miss] 5625  NOFX — Leaving Jesusland (Live)  (score=0.0)
# [miss] 5639  Hillsong Worship — Oceans Will Part - Live / Mighty To Save Album Version  (score=0.0)
# [ok] 5300/6000  Nogizaka46 — Arigachina Renai  bytes=479827  rate=0.80 trk/s
# [miss] 5645  Santaferia — Amor Sin Fronteras - En Vivo Movistar Arena Santiago, Chile  (score=0.0)
# [miss] 5667  Yuki Hayashi — Y.A.M. -Young All might-  (score=0.0)
# [miss] 5687  Lyrica Anderson — Feenin (feat. Kevin Gates)  (score=0.0)
# [ok] 5350/6000  Alison Wonderland — Cry - Rynx Remix  bytes=479827  rate=0.80 trk/s
# [miss] 5697  Talking Heads — Psycho Killer - 2005 Remastered Version  (score=0.0)
# [miss] 5702  Georges Bizet — Roma Orchestre Suite No.3: Allegro vivace  (score=0.0)
# [miss] 5723  Yuki Hayashi — ヴィランの侵攻  (score=0.0)
# [miss] 5727  Hillsong Worship — This I Believe (The Creed) - Radio Edit/Live  (score=0.0)
# [ok] 5400/6000  Hippo Campus — Vacation  bytes=479827  rate=0.80 trk/s
# [miss] 5762  Toots & The Maytals — Broadway Jungle - 2000 Version  (score=0.0)
# [miss] 5775  Phil Collins — Do You Remember? - 2016 Remastered  (score=0.0)
# [ok] 5450/6000  Chorus — Ambarsare Diyan Warhiyan  bytes=479827  rate=0.80 trk/s
# [miss] 5802  MF DOOM — Guinnesses feat. Angelika & 4ize  (score=0.0)
# [miss] 5807  Nick Murphy / Chet Faker — Gold - Flume Re-Work  (score=0.0)
# [ok] 5500/6000  Lemongrass — Swimming Pool  bytes=479827  rate=0.80 trk/s
# [miss] 5858  Nirvana — Love Buzz - Remastered  (score=0.0)
# [miss] 5860  De La Ghetto — La Formula (feat. Chris Jeday)  (score=0.0)
# [miss] 5892  Franco Escamilla — Amigos Incómodos, Grupos De Whatsapp Y Reglas De Combate  (score=0.0)
# [ok] 5550/6000  Kevin Gates — Wassup with It  bytes=479827  rate=0.80 trk/s
# [miss] 5910  i☆Ris — 翼を持つ者 〜Not an angel Just a dreamer〜  (score=0.0)
# [miss] 5930  Masakatsu Takagi — Home After Rain  (score=0.0)
# [ok] 5600/6000  Screeching Weasel — This Ain't Hawaii  bytes=479827  rate=0.80 trk/s
# [miss] 5972  Sia — Mountains (with Sia, Diplo & Labrinth)  (score=0.0)
# [miss] 5979  Maria Callas — La Wally (1997 Digital Remaster): Ebben?...Ne andrò lontana  (score=0.0)
# [miss] 5984  Kenshi Yonezu — 乾涸びたバスひとつ  (score=0.0)
# [miss] 5994  Jay Park — 좋아 Joah (Remastered)  (score=0.0)
# [ok] 5650/6000  Nick Thune — A Hero's Hero  bytes=479827  rate=0.80 trk/s
# [miss] 6029  Inon Zur — Wandering - The Blasted Forest, Pt. 1  (score=0.0)
# [ok] 5700/6000  Coheed and Cambria — A Favor House Atlantic  bytes=479827  rate=0.80 trk/s
# [miss] 6090  Nobuyuki Tsujii — それでも、生きてゆく - 2011年5月30日 CRESCENTE STUDIO スタジオ録音版  (score=0.0)
# [miss] 6104  BBC Philharmonic — Lloyd: Symphony No. 5 in B Flat: Rondo  (score=0.0)
# [ok] 5750/6000  Vince Staples — SAMO  bytes=479827  rate=0.80 trk/s
# [miss] 6129  Sublime — Doin' Time - Uptown Dub-Album Version  (score=0.0)
# [miss] 6138  NIYARI計画 — 深夜食堂「思ひで」 ORIGINAL COVER  (score=0.0)
# [ok] 5800/6000  Alan Jackson — Gone Country  bytes=479827  rate=0.80 trk/s
# [miss] 6183  Kimbo Children's Music — Ronds de jambe À terre (Moderate 3/4)  (score=0.0)
# [miss] 6199  Snarky Puppy — Brother, I’m Hungry - Live  (score=0.0)
# [miss] 6203  Nujabes — Island (feat. Uyama Hiroto & haruka nakamura)  (score=0.0)
# [miss] 6208  Gioachino Rossini — Rossini: Stabat Mater: I. Stabat Mater dolorosa (Soprano, Mezzo-soprano, Tenor, Bass, Chorus)  (score=0.0)
# [ok] 5850/6000  Shawn Mendes — Bring It Back  bytes=479827  rate=0.80 trk/s
# [miss] 6227  Eric Clapton — River of Tears - Live at Staples Center, Los Angeles, CA, 8/18 - 19/2001  (score=0.0)
# [ok] 5900/6000  Nobuo Uematsu — Memoro De La Stono​~​Distant Worlds (Final Fantasy XI)  bytes=479827  rate=0.80 trk/s
# [miss] 6303  Ella Vos — 00000 Million - Recorded at Spotify Studios NYC  (score=0.0)
# [miss] 6306  Citipointe Live — If Not for Love (feat. Chardon Lewis)  (score=0.0)
# [ok] 5950/6000  Aaliyah — At Your Best (You Are Love)  bytes=479827  rate=0.80 trk/s
# [miss] 6332  CHiCO — Tsunoru Kimochi (with HoneyWorks)  (score=0.0)
# [miss] 6342  New Order — Ceremony - Version 1; 2016 Remastered Version  (score=0.0)
# [miss] 6349  My Darkest Days — Porn Star Dancing - Bonus Track  (score=0.0)
# [miss] 6366  Whitesnake — Here I Go Again 87 - 2017 Remaster  (score=0.0)
# [miss] 6376  André-Ernest-Modeste Grétry — Cephale et Procris, ou L'amour conjugal (arr. S. Suzuki for violin and piano): Tambourin (arr. for violin and piano)  (score=0.0)
# [ok] 6000/6000  Alice Cooper — Welcome to My Nightmare  bytes=479827  rate=0.80 trk/s
#
# ======== Summary ========
# Target total: 6000
# Selected rows (downloaded/resumed): 6000
# Throughput: 0.80 tracks/sec  |  Elapsed: 124.7 min
# ✅ Final CSV: ../input/songs_dataset_6k.csv
# 🎵 Audio dir: ../output/previews
# 📝 Manifest:  ../work/deezer_manifest_verbose.csv
